# %% [markdown]
# ## Basics of Matplotlib

# %%
# %matplotlib inline

import pandas as pd
import numpy as np

# plt alias for matplot.pyplot
import matplotlib.pyplot as plt

# wrapper of matplotlib
import seaborn as sns

# %%
# load car loan data into pandas dataframe from csv file 

filename = 'data/cars.csv'
df = pd.read_csv(filename)

# %%
df.head() # view the first five row of the dataframe
# Out:
#    month  starting_balance  interest_paid  principal_paid  new_balance  \
# 0      1          34689.96         202.93          484.30     34205.66
# 1      2          34205.66         200.10          487.13     33718.53
# 2      3          33718.53         197.25          489.98     33228.55
# 3      4          33228.55         194.38          492.85     32735.70
# 4      5          32735.70         191.50          495.73     32239.97
#
#    interest_rate       car_type
# 0         0.0702  Toyota Sienna
# 1         0.0702  Toyota Sienna
# 2         0.0702  Toyota Sienna
# 3         0.0702  Toyota Sienna
# 4         0.0702  Toyota Sienna

# %%
# check if we have nans in our data frame 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   month             60 non-null     int64
#  1   starting_balance  60 non-null     float64
#  2   interest_paid     60 non-null     float64
#  3   principal_paid    60 non-null     float64
#  4   new_balance       60 non-null     float64
#  5   interest_rate     60 non-null     float64
#  6   car_type          60 non-null     object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 3.4+ KB

# %%
# convert to numpy array
month_number = df.loc[:, 'month'].values
interest_paid = df.loc[:,'interest_paid'].values
principal_paid = df.loc[:, 'principal_paid'].values

# %% [markdown]
# ## Plot method

# %%
# Let's plot
plt.plot(month_number, interest_paid)

# %%
plt.plot(month_number, interest_paid)
plt.plot(month_number, principal_paid)

# %%
# Thrown in some styles, use
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# we will go with the classic, maybe not!
plt.style.use('fivethirtyeight')
plt.plot(month_number, interest_paid)
plt.plot(month_number, principal_paid)

# %%
# let's change marker type
plt.style.use('seaborn')

plt.plot(month_number, interest_paid,c = 'k', marker = '.', markersize = 10)
plt.plot(month_number, principal_paid,c = 'b', marker = '.', markersize = 10)

# %%
# Using hex strings
# '#000000' is black
# '#0000FF' is blue
plt.plot(month_number, interest_paid,c = '#000000', marker = '.', markersize = 10)
plt.plot(month_number, principal_paid,c = '#0000FF', marker = '.', markersize = 10)

# %%
# Using rgb tuples
# (0, 0, 0) is black
# (0, 0, 1) is blue
plt.plot(month_number, interest_paid,c = (0, 0, 0), marker = '.', markersize = 10)
plt.plot(month_number, principal_paid,c = (0, 0, 1), marker = '.', markersize = 10)

# %% [markdown]
# ## MATLAB-style plotting

# %%
plt.style.use('seaborn')

plt.plot(month_number, interest_paid, c= 'k')
plt.plot(month_number, principal_paid, c = 'b')

# %% [markdown]
# ## Object-oriented style plotting

# %%
# tuple unpacking 
x,y = (3,9)

fig,axes = plt.subplots(nrows=1, ncols=1)
axes.plot(month_number, interest_paid, c='k')
axes.plot(month_number, principal_paid, c='b')

# %% [markdown]
# ## What happens when we combine them?
# ## Combining

# %%
fig, axes = plt.subplots(nrows = 1, ncols =1)
plt.plot(month_number, interest_paid, c= 'k')
axes.plot(month_number, principal_paid, c = 'b')

# %% [markdown]
# ## Setting plot titles, labels, and limits

# %% [markdown]
# ## MATLAB-style

# %%
# Setting xlim and ylim
plt.plot(month_number, interest_paid, c= 'k')
plt.plot(month_number, principal_paid, c = 'b')
plt.xlim(left=1,right=70)
plt.ylim(bottom=0,top=1000)

# Setting xlabel and ylabel and changing font size
plt.xlabel('Month', fontsize = 15)
plt.ylabel('Dollars', fontsize = 15)

# Set title and changing font size
plt.title('Interest and Principal Paid Each Month', fontsize = 15)


# changing tick font size
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
# Out:
# (array([   0.,  200.,  400.,  600.,  800., 1000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ## Object-oriented

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 1)

# plot graph
axes.plot(month_number, interest_paid, c= 'k');
axes.plot(month_number, principal_paid, c = 'b');

# set limits on x-axis and y-axis
axes.set_xlim(left =1 , right = 70)
axes.set_ylim(bottom = 0, top = 1000)

# set labels
axes.set_xlabel('Month', fontsize = 22);
axes.set_ylabel('Dollars', fontsize = 22);

# set title
axes.set_title('Interest and Principal Paid Each Month', fontsize = 22);

# set ticks
axes.tick_params(axis = 'x', labelsize = 20)
axes.tick_params(axis = 'y', labelsize = 20)

# %% [markdown]
# ## Grids and Legends

# %% [markdown]
# ## MATLAB-style

# %%
# only horizontal grid lines
plt.plot(month_number, interest_paid, c= 'k', label="Interest")
plt.plot(month_number, principal_paid, c = 'b', label="Principal")
plt.grid(axis = 'y')
plt.legend(loc="center right")
## plt.legend(loc=(1.02,0))
plt.tight_layout()
plt.savefig('data/graph.png', dpi = 300)

# %%
# change color of grid lines, transparency, and linestyle
plt.plot(month_number, interest_paid, c= 'k')
plt.plot(month_number, principal_paid, c = 'b')
plt.grid(c = 'g', 
         alpha = .1, # close to .1 means lighter, closer to .9 means darker
         linestyle = '-')

# %% [markdown]
# ## Object-oriented

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 1);
axes.plot(month_number, interest_paid, c= 'k', label="Interest");
axes.plot(month_number, principal_paid, c = 'b', label="Principal");
axes.grid(axis = 'y')
#axes.legend()
axes.legend(loc="center right")
#axes.legend(loc=(1.02,0))

fig.tight_layout() ## makes sure that the image isn't cutoff important!!!!!
fig.savefig('data/graph2.png', dpi = 300)

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 1);
axes.plot(month_number, interest_paid, c= 'k');
axes.plot(month_number, principal_paid, c = 'b');
axes.grid(c = 'g', 
          alpha = .9,
          linestyle = '-')

# %%
filename
